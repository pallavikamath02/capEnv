# %%
#return the sum of even kilometer they pass
x=int(input("enter the kilometers: "))

def kilo(x):
    sum=0
    for i in range(x+1):
        if i%2 == 0:
            sum+=i
    # print(sum)
    return sum

print(kilo(x))
# Out:
# 12

# %%
# count how many fans can set in a a seat
n=int(input("enter the size of an ayyay: "))
a=list(map(int,input("enter the arrray elements: ").split()))
def array(a,n):
    count=0
    for i in range(n):
        if a[i] == 0:
            count+=1
    return count
print(array(a,n))
# Out:
# 0

# %%
#Number of rounds Ships needs to be transported to shift the people from point A to point B

# C=int(input("enter the capacity of th ship: "))
# N=int(input("enter the number of people to be transported: "))
C,N=map(int,input().split())
def rounds(C,N):
   if N%C ==0:
       return N//C
   else:
       return N//C +1
   
print(rounds(C,N))
# Out:
# 4

# %%
n=int(input("enter the number of rooms fixed: "))
a=list(map(int,input("enter the room numbers: ").split()))
t=int(input("enter the number of rooms to be checked: "))
def diff(n,t):
    return abs(n-t)

print(diff(n,t))
# Out:
# 11

# %%
n=int(input("enter the number of elements: "))
a=list(map(int,input("enter the array elements: ").split()))

def product(n,a):
    prod=1
    for i in range(n):
       if a[i]%7 ==0:
           prod=prod*a[i]
    return prod

print(product(n,a))
# Out:
# 98

# %%
n=int(input("enter the number of elements: "))
print(n*7)
# Out:
# 28

# %%
s=input("enter the string: ")
length=len(s)
def string(s,length):
    count=1
    max1=0
    for i in range(length):
        if s[i]==s[i-1]:
            count+=1
            max1=max(max1,count)
        else:
            count=1
    m=length-max1
    return m
print(string(s,length))
# Out:
# 8

# %%
# # Eva has a string S containing lowercase English letters. She wants to transform this string into a Magic String, where all the characters in the string are the same. To do so, she can replace any letter in the string with another letter present in that string.
# Your task is to help Eva find and return an integer value, representing the minimum number of steps required to form a Magic String. Return 0, if S is already a Magic String.
# Input Format
# A string S, containing lowercase English letters.
# Constraints
# NA
# Output Format
# Return an integer value, representing the minimum number of steps required to form a Magic String. Return 0, if S is already a Magic String.
# Sample Input 0
# aaabbbccdddd 
# Sample Output 0
# 8 
# Explanation 0
# Here in this example, the string Sis aaabbbccdddd. We need perform the following operations to make a Magic String:
# 1st way
# On replacing the letters b, c, d with a, the Magic string formed is aaaaaaaaaaaa. Here, the minimum number of steps to convert the original string to Magic String is 9.
# Optimal Way
# On replacing the letters, a, b, c with d, the Magic string formed is dddddddddddd Here, the minimum number of steps required to form the Magic String is 8. Since 8 is smaller than 9, 8 is returned as the output.

s=input("enter the string: ")
length=len(s)   
def string(s,length):
    freq={}
    for char in s:
        if char in freq:
            freq[char]+=1
        else:
            freq[char]=1
    max_freq=max(freq.values())
    return length - max_freq

print(string(s,length))
# Out:
# 8

# %%
# In a remote village, there existed two mystical strings S1 and S2 In these strings was hidden a secret encoded in their characters Your task is to find and return an integer value representing the encoded SA secret of the strings by finding the sum of the ASCII values of the characters in the longest common substring between these two Strings. Return 0 if there is no common substring.
# Note
# Strings S, and S₂ contain English alphabets in lower case only.
# If there are multiple longest common substrings, then return the ASC sum of the substring that occurs first.
# Input Format
# A string value S1
# A string value S2.
# Constraints
# NA
# Output Format
# Return an integer value representing by finding the sum the encoded secret of the strings of the ASCII values of the characters in the longest common substring between these two strings.
# Sample Input 0
# adventure future 
# Sample Output 0
# 448 
# Explanation 0
# Here, the string S1 i is adventure" and S2 is "future". The longest common substring between S1 and S₂ is "ture", with their ASCII values summing up to 448 (116+117+114+101). Therefore, 448 is returned as the output.
# Sample Input 1
# mystery legend 
# Sample Output 1
# 101 
# Explanation 1
# Here, the string St is "mystery" and S2 is "legend". The longest common substring between S, and Sy is with its ASCII value summing up to 101. Therefore, 101 returned as the output
# #

# %%
s1=input("enter s1: ")
s2=input("enter s2: ")
def ascii_sum_longest_common_substring(s1, s2):
    max_len = 0
    max_sum = 0
    i = 0
    while i < len(s1):
        j = 0
        while j < len(s2):
            k = 0
            curr_sum = 0
            while (i + k < len(s1) and
                   j + k < len(s2) and
                   s1[i + k] == s2[j + k]):
                curr_sum += ord(s1[i + k])
                k += 1
            if k > max_len:
                max_len = k
                max_sum = curr_sum
            j += 1
        i += 1
    return max_sum
print(ascii_sum_longest_common_substring(s1,s2))

# %%
# 10

n=int(input("enter total problems: "))
p=int(input("enter time: "))
rem_time=240-p
total_time=0
count=0
for i in range(1,n+1):
    if total_time + 5*i <= rem_time:
        total_time += 5*i
        count += 1
    else:
        break
print(count)

# %%
# 11

def winning_party(votes):
    n = len(votes)
    for i in range(n):
        count = 0
        for j in range(n):
            if votes[j] == votes[i]:
                count += 1
        if count * 2 >= n:
            return votes[i]
    return -1
votes=list(map(int,input("enter votes: ").split()))
print(winning_party(votes))

# %%
# 12

def min_possible_sum(arr):
    max_val = arr[0]
    for i in range(1, len(arr)):
        if arr[i] > max_val:
            max_val = arr[i]
    return max_val
arr=list(map(int,input("enter array: ").split()))
print(min_possible_sum(arr))

# %%
# 13

def team_initials(names):
    res = ""
    for name in names:
        res += name[0].upper()
    return res
names=list(map(str,input("enter names: ").split()))
print(team_initials(names))

# %%
# 14

def latest_file_version(files):
    max_ver = -1
    for f in files:
        if len(f) >= 6 and f[0:5] == "File_":
            num = 0
            valid = True
            for i in range(5, len(f)):
                if f[i] < '0' or f[i] > '9':
                    valid = False
                    break
                num = num * 10 + (ord(f[i]) - 48)
            if valid and num > max_ver:
                max_ver = num
    return max_ver
files=list(map(str,input("enter files: ").split()))
print(latest_file_version(files))

# %%
# 15

def winning_move(move):
    if move == "rock":
        return "Paper"
    if move == "paper":
        return "Scissors"
    if move == "scissors":
        return "Rock"
move=input("enter the player A move: ")
print(winning_move(move))
