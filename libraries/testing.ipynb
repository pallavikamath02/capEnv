# %%
def square(n):
    return n*n
import unittest
class TestSquare(unittest.TestCase):
    def test_square(self):
        self.assertEqual(square(4,16))
unittest.main()
# Out:
# usage: ipykernel_launcher.py [-h] [-v] [-q] [--locals] [--durations N] [-f]
#                              [-c] [-b] [-k TESTNAMEPATTERNS]
#                              [tests ...]
# ipykernel_launcher.py: error: argument -f/--failfast: ignored explicit argument 'c:\\Users\\Lochan\\AppData\\Roaming\\jupyter\\runtime\\kernel-v3cf79dad4b6994feb2c769e9d5137218a6dd2b014.json'
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
class TestDemo(unittest.TestCase):
    def setUp(self):
        self.a=10
        self.b=5
    def test_add(self):
        self.assertEqual(self.a+self.b,15)
    def tearDown(self):
        pass
if __name__ == "__main__":
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .E
# ======================================================================
# ERROR: test_square (__main__.TestSquare.test_square)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Lochan\AppData\Local\Temp\ipykernel_21136\3458049281.py", line 6, in test_square
#     self.assertEqual(square(4,16))
#                      ^^^^^^^^^^^^
# TypeError: square() takes 1 positional argument but 2 were given
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.003s
#
# FAILED (errors=1)

# %%
def withDraw(balance,amount):
    if amount>balance:
        raise ValueError("insufficient balance")
    return balance-amount
def test_exception(self):
    with self.assertRaise(ValueError):
        withDraw(100,200)
if __name__ == "__main__":
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .E
# ======================================================================
# ERROR: test_square (__main__.TestSquare.test_square)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\DELL\AppData\Local\Temp\ipykernel_10292\3458049281.py", line 6, in test_square
#     self.assertEqual(square(4,16))
#                      ~~~~~~^^^^^^
# TypeError: square() takes 1 positional argument but 2 were given
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.010s
#
# FAILED (errors=1)

# %%
class Bank:
    def deposit(self,amt):
        return amt
class TestBank(unittest.TestCase):
    def test_deposit(self):
        bank=Bank()
        self.assertEqual(bank.deposit(1000),1000)
@unittest.skip("feature not ready")
def test_future(self):
    pass
if __name__ == "__main__":
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ..E
# ======================================================================
# ERROR: test_square (__main__.TestSquare.test_square)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\DELL\AppData\Local\Temp\ipykernel_10292\3458049281.py", line 6, in test_square
#     self.assertEqual(square(4,16))
#                      ~~~~~~^^^^^^
# TypeError: square() takes 1 positional argument but 2 were given
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.072s
#
# FAILED (errors=1)

# %%
import unittest

class Teststringmethods(unittest.TestCase):
    def setUp(self):
        pass
    
    #Retturn Ture if the string contains 4a
    def test_string_a(self):
        self.assertIn('a'*4,'aaaa')
        
if __name__ == "__main__":
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ..E.
# ======================================================================
# ERROR: test_square (__main__.TestSquare.test_square)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\DELL\AppData\Local\Temp\ipykernel_10292\3458049281.py", line 6, in test_square
#     self.assertEqual(square(4,16))
#                      ~~~~~~^^^^^^
# TypeError: square() takes 1 positional argument but 2 were given
#
# ----------------------------------------------------------------------
# Ran 4 tests in 0.019s
#
# FAILED (errors=1)

# %%
#rganizing test cde
import unittest
class TestStringMethods(unittest.TestCase):
    def test_upper(self):
        self.assertEqual('foo'.upper(), 'FOO')
    def test_isupper(self):
        self.assertTrue('FOO'.isupper())
        self.assertFalse('Foo'.isupper())
    def test_strip(self):
        s = '   hello   '
        self.assertEqual(s.strip(), 'hello')
    def test_split(self):
        s = 'hello world'
        self.assertEqual(s.split(), ['hello', 'world'])
        with self.assertRaises(TypeError):
            s.split(2)
if __name__ == "__main__":
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ..E.....
# ======================================================================
# ERROR: test_square (__main__.TestSquare.test_square)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\DELL\AppData\Local\Temp\ipykernel_10292\3458049281.py", line 6, in test_square
#     self.assertEqual(square(4,16))
#                      ~~~~~~^^^^^^
# TypeError: square() takes 1 positional argument but 2 were given
#
# ----------------------------------------------------------------------
# Ran 8 tests in 0.038s
#
# FAILED (errors=1)

# %%
import unittest

#

#Application Code

#

class Widget:

#
    def __init__(self):
        self.width = 50
        self.height = 50

    def resize(self, width, height):
        self.width = width
        self.height = height

#Test Case Code

class WidgetTestCase(unittest.TestCase):

    def test_default_widget_size(self):
        widget = Widget()
        self.assertEqual(widget.width, 50)
        self.assertEqual(widget.height, 50)

    def test_widget_resize(self):
        widget = Widget()
        widget.resize(100, 150)
        self.assertEqual(widget.width, 100)
        self.assertEqual(widget.height, 150)
        
    #Test Suite Code
    # def suite():
    #     test_suite=unittest.TestSuite()
    #     test_suite.addTest(WidgetTestCase("test_default_widget_size"))
    #     test_suite.addTest(WidgetTestCase("test_widget_resize"))
    #     return test_suite

#Test Runner
if __name__ == "__main__":
    runner=unittest. TextTestRunner()
    def suite():
        test_suite=unittest.TestSuite()
        test_suite.addTest(WidgetTestCase("test_default_widget_size"))
        test_suite.addTest(WidgetTestCase("test_widget_resize"))
        return test_suite

    if __name__ == "__main__":
        runner=unittest.TextTestRunner()
        runner.run(suite())
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.015s
#
# OK

# %%
import unittest

class TestStringLength(unittest.TestCase):

    def test_string_length(self):
        strings = {
            6.5:5,
            5.5:6,
            3.5:3
        }

        for text, length in strings.items():
            with self.subTest(string=text):
                self.assertEqual(len(text),length)

    if __name__ == "__main__":
        if __name__ == "__main__":
            unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ...
# ----------------------------------------------------------------------
# Ran 3 tests in 0.012s
#
# OK

# %%
fjkbh,dhjfhkfhkfdhjfgjgjhkdfkdsjp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 fjkbh,dhjfhkfhkfdhjfgjgjhkdfkdsjp
#
# NameError: name 'fjkbh' is not defined

# %% [markdown]
# Pytest is a framework in python

# %%
import pytest
def add1(x):
    return x+5
def test_method():
    assert add1(3)==8
